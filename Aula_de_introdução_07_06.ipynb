# %% [markdown]
# <a href="https://colab.research.google.com/github/Lincoln-Alyson/Lincoln_atividades/blob/main/Aula_de_introdu%C3%A7%C3%A3o_07_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.hist(np.random.normal(10, 1, 123456))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
