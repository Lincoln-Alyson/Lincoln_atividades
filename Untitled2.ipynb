# %% [markdown]
# <a href="https://colab.research.google.com/github/Lincoln-Alyson/Lincoln_atividades/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
response=requests.get('https://www.letras.mus.br/tiririca/364676/')
print(response.status_code)
print(response.text)
# Out:
# 200
# ...
